# %% [markdown]
# ### Notebook for testing the batch run of the tess pipeline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from astropy.table import Table

# %%
# df = pd.read_csv("../data/TOI_2026.06.28_09.42.00.csv")

table = Table.read("../data/TOI_2026.06.28_09.42.00.csv", format='ascii', comment='#')

df = table.to_pandas()

df
# Out:
#       rowid      toi  toipfx        tid    ctoi_alias  pl_pnum tfopwg_disp  \
# 0         1  1000.01    1000   50365310  5.036531e+07        1          FP
# 1         2  1001.01    1001   88863718  8.886372e+07        1          PC
# 2         3  1002.01    1002  124709665  1.247097e+08        1          FP
# 3         4  1003.01    1003  106997505  1.069975e+08        1          FP
# 4         5  1004.01    1004  238597883  2.385979e+08        1          FP
# ...     ...      ...     ...        ...           ...      ...         ...
# 7926   7927   995.01     995  317951248  3.179512e+08        1          FP
# 7927   7928   996.01     996  142918609  1.429186e+08        1          FP
# 7928   7929   997.01     997  341729521  3.417295e+08        1          FP
# 7929   7930   998.01     998   54390047  5.439005e+07        1          FP
# 7930   7931   999.01     999  341186896  3.411869e+08        1          FP
#
#              rastr          ra  raerr1  ...  st_loggerr2 st_logglim  \
# 0     07h29m25.85s  112.357708    <NA>  ...        -0.07          0
# 1     08h10m19.31s  122.580465    <NA>  ...        -0.09          0
# 2     06h58m54.47s  104.726966    <NA>  ...          NaN          0
# 3     07h22m14.39s  110.559945    <NA>  ...        -1.64          0
# 4     08h08m42.77s  122.178195    <NA>  ...        -0.07          0
# ...            ...         ...     ...  ...          ...        ...
# 7926  07h23m14.75s  110.811443    <NA>  ...          NaN          0
# 7927  07h57m23.99s  119.349948    <NA>  ...          NaN          0
# 7928  08h05m16.69s  121.319521    <NA>  ...        -0.08          0
# 7929  07h53m16.69s  118.319555    <NA>  ...        -0.07          0
# 7930  07h55m27.38s  118.864086    <NA>  ...        -0.09          0
#
#       st_loggsymerr    st_rad  st_raderr1  st_raderr2  st_radlim  \
# 0                 1  2.169860    0.072573   -0.072573          0
# 1                 1  2.010000    0.090000   -0.090000          0
# 2                 1  5.730000         NaN         NaN          0
# 3                 1       NaN         NaN         NaN          0
# 4                 1  2.150000    0.060000   -0.060000          0
# ...             ...       ...         ...         ...        ...
# 7926              1       NaN         NaN         NaN          0
# 7927              1  2.050000         NaN         NaN          0
# 7928              1  0.926261    0.045789   -0.045789          0
# 7929              1  2.349860    0.091578   -0.091578          0
# 7930              1  1.300000    0.050000   -0.050000          0
#
#       st_radsymerr          toi_created            rowupdate
# 0                1  2019-07-24 15:58:33  2024-09-09 10:08:01
# 1                1  2019-07-24 15:58:33  2023-04-03 14:31:04
# 2                1  2019-07-24 15:58:33  2022-07-11 16:02:02
# 3                1  2019-07-24 15:58:33  2022-02-23 10:10:02
# 4                1  2019-07-24 15:58:33  2024-09-09 10:08:01
# ...            ...                  ...                  ...
# 7926             1  2019-07-24 15:58:33  2021-10-29 12:59:15
# 7927             1  2019-07-24 15:58:33  2021-10-29 12:59:15
# 7928             1  2019-07-24 15:58:33  2024-09-09 10:08:01
# 7929             1  2019-07-24 15:58:33  2024-09-09 10:08:01
# 7930             1  2019-07-24 15:58:33  2024-09-09 10:08:01
#
# [7931 rows x 87 columns]

# %%
df['tfopwg_disp'].unique()
# Out:
# array(['FP', 'PC', 'KP', 'APC', 'FA', 'CP', nan], dtype=object)

# %% [markdown]
# | Value  | Meaning          | Description                                                                                                                                                                                             |
# | ------ | ---------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **PC** | Planet Candidate | The object is still considered a promising exoplanet candidate. It has not yet been confirmed or statistically validated. More observations are needed.                                                 |
# | **CP** | Confirmed Planet | The candidate has been confirmed as a genuine exoplanet through follow-up observations (e.g., radial velocities, transit timing variations, high-resolution imaging, statistical validation, etc.).     |
# | **FP** | False Positive   | The transit signal is not caused by a planet. Common causes include eclipsing binaries, background eclipsing binaries, instrumental artifacts, stellar variability, or contamination from nearby stars. |
# | **KP** | Known Planet     | The signal corresponds to a planet that was already known before the TESS detection. TESS has observed the transit of an already discovered exoplanet.                                                  |

# %%
df_1 = df[df['tfopwg_disp'] == 'APC']

df_1
# Out:
#       rowid      toi  toipfx        tid    ctoi_alias  pl_pnum tfopwg_disp  \
# 13       14  1012.01    1012  427508467  4.275085e+08        1         APC
# 44       45  1039.01    1039  461867584  4.618676e+08        1         APC
# 68       69  1060.01    1060  101230735  1.012307e+08        1         APC
# 96       97  1085.01    1085  381979901  3.819799e+08        1         APC
# 106     107  1094.01    1094  136274063  1.362741e+08        1         APC
# ...     ...      ...     ...        ...           ...      ...         ...
# 7871   7872   940.01     940  248434716  2.484347e+08        1         APC
# 7878   7879   947.01     947  262330063  2.623301e+08        1         APC
# 7879   7880   948.01     948  146438872  1.464389e+08        1         APC
# 7889   7890   958.01     958   92880568  9.288057e+07        1         APC
# 7920   7921   989.01     989  207277638  2.072776e+08        1         APC
#
#              rastr          ra  raerr1  ...  st_loggerr2 st_logglim  \
# 13    07h48m22.87s  117.095285    <NA>  ...     -0.08000          0
# 44    09h58m45.25s  149.688545    <NA>  ...          NaN          0
# 68    19h57m09.84s  299.290995    <NA>  ...     -0.12000          0
# 96     05h10m25.3s   77.605399    <NA>  ...     -2.00486          0
# 106   15h21m59.72s  230.498827    <NA>  ...     -0.08000          0
# ...            ...         ...     ...  ...          ...        ...
# 7871  05h09m36.86s   77.403593    <NA>  ...          NaN          0
# 7878  05h13m16.52s   78.318822    <NA>  ...     -0.49000          0
# 7879  05h02m07.62s   75.531735    <NA>  ...     -0.11000          0
# 7889   05h32m51.8s   83.215825    <NA>  ...     -0.08000          0
# 7920  07h22m01.57s  110.506534    <NA>  ...          NaN          0
#
#       st_loggsymerr  st_rad  st_raderr1  st_raderr2  st_radlim  st_radsymerr  \
# 13                1    2.72        0.13       -0.13          0             1
# 44                1     NaN         NaN         NaN          0             1
# 68                1    1.14        0.07       -0.07          0             1
# 96                1    1.28         NaN         NaN          0             1
# 106               1    2.28        0.09       -0.09          0             1
# ...             ...     ...         ...         ...        ...           ...
# 7871              1    0.85        0.04       -0.04          0             1
# 7878              1    1.79        0.09       -0.09          0             1
# 7879              1    1.92        0.10       -0.10          0             1
# 7889              1    1.43        0.08       -0.08          0             1
# 7920              1    2.06        0.08       -0.08          0             1
#
#               toi_created            rowupdate
# 13    2019-07-24 15:58:33  2023-03-10 12:02:48
# 44    2019-07-24 18:44:12  2023-05-05 16:02:01
# 68    2019-08-16 20:20:42  2023-10-16 16:02:02
# 96    2019-08-16 20:20:49  2023-07-12 16:02:01
# 106   2019-08-06 19:29:59  2022-10-05 10:10:01
# ...                   ...                  ...
# 7871  2019-07-24 14:30:01  2024-09-07 10:08:02
# 7878  2019-07-24 14:30:01  2021-12-07 16:02:02
# 7879  2019-07-24 14:30:01  2021-12-07 16:02:02
# 7889  2019-07-24 14:53:22  2024-09-07 10:08:02
# 7920  2019-07-24 15:58:33  2024-01-03 10:08:03
#
# [481 rows x 87 columns]

# %%
# select 100 random TIC ids from the df_1 dataframe
tic_ids = df_1['tid'].sample(n=10, random_state=1, replace=False).tolist()

tic_ids
# Out:
# [391903064,
#  75650448,
#  183120439,
#  94986319,
#  178819686,
#  258510872,
#  147977348,
#  12421862,
#  258920431,
#  467331291]

# %%
#!/usr/bin/env python3
"""
Test script to run the TESS Exoplanet Pipeline with the modernized Bayesian (exoplanet/PyMC/GP)
backend on target star TIC 52368076.
"""

from __future__ import annotations
import os
import sys
from tess_pipeline import TESSAnalysis

sectors = 'longest'  # Use 'longest' to automatically select the longest available sector for the target

def main(TIC) -> None:
    print("Initializing TESS Analysis for TIC 52368076 using Bayesian MCMC...")
    
    # Configure the analysis session with 500 tune and 500 draws for a fast test run
    analysis = TESSAnalysis(
        target=f"TIC {TIC}",
        inference=True,
        inference_backend="exoplanet",  # uses exoplanet/PyMC/celerite2
        search_method="tls",
        sectors=sectors,
        max_planets=1,
        chains=2,
        draws=1,
        tune=1,
        plots=True,
        output_dir=f"output_bayesian_sector_{sectors}_500_2",
        verbose=True
    )
    
    # # Run the target characterization, download, detrending, and period search
    print("1. Resolving target coordinates...")
    analysis.resolve_target()
    
    # print("2. Checking archival orbital period...")
    # analysis.lookup_archive_period()
    
    # print("3. Downloading TESS light curves from MAST...")
    # analysis.load_lightcurves()
    
    # print("4. Preprocessing light curves (stitching, cleaning, detrending)...")
    # analysis.preprocess()
    
    # print("5. Searching for transit signals...")
    # analysis.search_period()
    
    # print("6. Querying Gaia DR3 for stellar properties...")
    # analysis.query_gaia()
    
    # print("7. Characterizing host star properties...")
    # analysis.characterize_star()
    
    # # Disable SDSS checking since it is deprecated/disabled
    # print("8. Skipping SDSS checking (disabled in this version)...")
    # analysis.query_sdss()
    
    # print("9. Running Bayesian MCMC fit...")
    # analysis.fit_transit()
    
    # print("10. Deriving physical planetary parameters with uncertainty propagation...")
    # analysis.derive_planet_parameters()
    
    # print("11. Checking MCMC sampler convergence...")
    # analysis.check_convergence()
    
    # print("12. Generating figures...")
    # analysis.generate_figures()
    
    # # Print results summary
    # print("\n" + "="*50)
    # print("BAYESIAN FIT RESULTS SUMMARY")
    # print("="*50)
    # analysis.results.summary()

    
    # print("\nSaving results and diagnostic plots...")
    # analysis.save()
    print("Done! Bayesian test completed successfully.\n")

if __name__ == "__main__":

    for TIC in tic_ids:
        main(TIC)
# Out:
# Initializing TESS Analysis for TIC 52368076 using Bayesian MCMC...
# 1. Resolving target coordinates...
# 17:36:58  INFO      tess_pipeline.analysis.stages.target  Resolving target: TIC 391903064
# 17:36:58  DEBUG     tess_pipeline.data.metadata  Resolved 'TIC 391903064' to TIC 391903064
# 17:36:58  INFO      tess_pipeline.catalogs.nasa_archive  Using local NASA archive CSV /mnt/home/project/cnitesh/nitesh/tess_exoplanet_pipeline/data/TOI_2026.06.28_09.42.00.csv for TIC 391903064 (matched 2 row(s))
# 17:36:58  INFO      tess_pipeline.data.metadata  Loaded coordinates for TIC 391903064 from local archive
# 17:36:58  INFO      tess_pipeline.analysis.stages.target  Resolved to TIC 391903064
# 17:36:58  INFO      tess_pipeline.data.metadata  Loaded coordinates for TIC 391903064 from local archive
# 17:36:58  INFO      tess_pipeline.analysis.stages.target  Resolved to TIC 391903064
# Done! Bayesian test completed successfully.
#
# Initializing TESS Analysis for TIC 52368076 using Bayesian MCMC...
# 1. Resolving target coordinates...
# 17:36:58  INFO      tess_pipeline.analysis.stages.target  Resolving target: TIC 75650448
# 17:36:58  DEBUG     tess_pipeline.data.metadata  Resolved 'TIC 75650448' to TIC 75650448
# 17:36:58  INFO      tess_pipeline.catalogs.nasa_archive  Using local NASA archive CSV /mnt/home/project/cnitesh/nitesh/tess_exoplanet_pipeline/data/TOI_2026.06.28_09.42.00.csv for TIC 75650448 (matched 1 row(s))
# 17:36:58  INFO      tess_pipeline.data.metadata  Loaded coordinates for TIC 75650448 from local archive
# 17:36:58  INFO      tess_pipeline.analysis.stages.target  Resolved to TIC 75650448
# Done! Bayesian test completed successfully.
#
# Initializing TESS Analysis for TIC 52368076 using Bayesian MCMC...
# 1. Resolving target coordinates...
# 17:36:58  INFO      tess_pipeline.analysis.stages.target  Resolving target: TIC 183120439
# 17:36:58  DEBUG     tess_pipeline.data.metadata  Resolved 'TIC 183120439' to TIC 183120439
# 17:36:58  INFO      tess_pipeline.catalogs.nasa_archive  Using local NASA archive CSV /mnt/home/project/cnitesh/nitesh/tess_exoplanet_pipeline/data/TOI_2026.06.28_09.42.00.csv for TIC 183120439 (matched 1 row(s))
# 17:36:58  INFO      tess_pipeline.data.metadata  Loaded coordinates for TIC 183120439 from local archive
# 17:36:58  INFO      tess_pipeline.analysis.stages.target  Resolved to TIC 183120439
# Done! Bayesian test completed successfully.
#
# Initializing TESS Analysis for TIC 52368076 using Bayesian MCMC...
# 1. Resolving target coordinates...
# 17:36:58  INFO      tess_pipeline.analysis.stages.target  Resolving target: TIC 94986319
# 17:36:58  DEBUG     tess_pipeline.data.metadata  Resolved 'TIC 94986319' to TIC 94986319
# 17:36:59  INFO      tess_pipeline.catalogs.nasa_archive  Using local NASA archive CSV /mnt/home/project/cnitesh/nitesh/tess_exoplanet_pipeline/data/TOI_2026.06.28_09.42.00.csv for TIC 94986319 (matched 2 row(s))
# 17:36:59  INFO      tess_pipeline.data.metadata  Loaded coordinates for TIC 94986319 from local archive
# 17:36:59  INFO      tess_pipeline.analysis.stages.target  Resolved to TIC 94986319
# Done! Bayesian test completed successfully.
#
# Initializing TESS Analysis for TIC 52368076 using Bayesian MCMC...
# 1. Resolving target coordinates...
# 17:36:59  INFO      tess_pipeline.analysis.stages.target  Resolving target: TIC 178819686
# 17:36:59  DEBUG     tess_pipeline.data.metadata  Resolved 'TIC 178819686' to TIC 178819686
# 17:36:59  INFO      tess_pipeline.catalogs.nasa_archive  Using local NASA archive CSV /mnt/home/project/cnitesh/nitesh/tess_exoplanet_pipeline/data/TOI_2026.06.28_09.42.00.csv for TIC 178819686 (matched 2 row(s))
# 17:36:59  INFO      tess_pipeline.data.metadata  Loaded coordinates for TIC 178819686 from local archive
# 17:36:59  INFO      tess_pipeline.analysis.stages.target  Resolved to TIC 178819686
# Done! Bayesian test completed successfully.
#
# Initializing TESS Analysis for TIC 52368076 using Bayesian MCMC...
# 1. Resolving target coordinates...
# 17:36:59  INFO      tess_pipeline.analysis.stages.target  Resolving target: TIC 258510872
# 17:36:59  DEBUG     tess_pipeline.data.metadata  Resolved 'TIC 258510872' to TIC 258510872
# 17:36:59  INFO      tess_pipeline.catalogs.nasa_archive  Using local NASA archive CSV /mnt/home/project/cnitesh/nitesh/tess_exoplanet_pipeline/data/TOI_2026.06.28_09.42.00.csv for TIC 258510872 (matched 1 row(s))
# 17:36:59  INFO      tess_pipeline.data.metadata  Loaded coordinates for TIC 258510872 from local archive
# 17:36:59  INFO      tess_pipeline.analysis.stages.target  Resolved to TIC 258510872
# Done! Bayesian test completed successfully.
#
# Initializing TESS Analysis for TIC 52368076 using Bayesian MCMC...
# 1. Resolving target coordinates...
# 17:36:59  INFO      tess_pipeline.analysis.stages.target  Resolving target: TIC 147977348
# 17:36:59  DEBUG     tess_pipeline.data.metadata  Resolved 'TIC 147977348' to TIC 147977348
# 17:36:59  INFO      tess_pipeline.catalogs.nasa_archive  Using local NASA archive CSV /mnt/home/project/cnitesh/nitesh/tess_exoplanet_pipeline/data/TOI_2026.06.28_09.42.00.csv for TIC 147977348 (matched 1 row(s))
# 17:36:59  INFO      tess_pipeline.data.metadata  Loaded coordinates for TIC 147977348 from local archive
# 17:36:59  INFO      tess_pipeline.analysis.stages.target  Resolved to TIC 147977348
# Done! Bayesian test completed successfully.
#
# Initializing TESS Analysis for TIC 52368076 using Bayesian MCMC...
# 1. Resolving target coordinates...
# 17:36:59  INFO      tess_pipeline.analysis.stages.target  Resolving target: TIC 12421862
# 17:36:59  DEBUG     tess_pipeline.data.metadata  Resolved 'TIC 12421862' to TIC 12421862
# 17:36:59  INFO      tess_pipeline.catalogs.nasa_archive  Using local NASA archive CSV /mnt/home/project/cnitesh/nitesh/tess_exoplanet_pipeline/data/TOI_2026.06.28_09.42.00.csv for TIC 12421862 (matched 1 row(s))
# 17:36:59  INFO      tess_pipeline.data.metadata  Loaded coordinates for TIC 12421862 from local archive
# 17:36:59  INFO      tess_pipeline.analysis.stages.target  Resolved to TIC 12421862
# Done! Bayesian test completed successfully.
#
# Initializing TESS Analysis for TIC 52368076 using Bayesian MCMC...
# 1. Resolving target coordinates...
# 17:36:59  INFO      tess_pipeline.analysis.stages.target  Resolving target: TIC 258920431
# 17:36:59  DEBUG     tess_pipeline.data.metadata  Resolved 'TIC 258920431' to TIC 258920431
# 17:36:59  INFO      tess_pipeline.catalogs.nasa_archive  Using local NASA archive CSV /mnt/home/project/cnitesh/nitesh/tess_exoplanet_pipeline/data/TOI_2026.06.28_09.42.00.csv for TIC 258920431 (matched 1 row(s))
# 17:36:59  INFO      tess_pipeline.data.metadata  Loaded coordinates for TIC 258920431 from local archive
# 17:36:59  INFO      tess_pipeline.analysis.stages.target  Resolved to TIC 258920431
# Done! Bayesian test completed successfully.
#
# Initializing TESS Analysis for TIC 52368076 using Bayesian MCMC...
# 1. Resolving target coordinates...
# 17:36:59  INFO      tess_pipeline.analysis.stages.target  Resolving target: TIC 467331291
# 17:36:59  DEBUG     tess_pipeline.data.metadata  Resolved 'TIC 467331291' to TIC 467331291
# 17:36:59  INFO      tess_pipeline.catalogs.nasa_archive  Using local NASA archive CSV /mnt/home/project/cnitesh/nitesh/tess_exoplanet_pipeline/data/TOI_2026.06.28_09.42.00.csv for TIC 467331291 (matched 1 row(s))
# 17:36:59  INFO      tess_pipeline.data.metadata  Loaded coordinates for TIC 467331291 from local archive
# 17:36:59  INFO      tess_pipeline.analysis.stages.target  Resolved to TIC 467331291
# Done! Bayesian test completed successfully.
